# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Example time-series data
X = np.random.rand(1000, 20, 5)
y = np.random.randint(0, 2, size=(1000,))

model = Sequential([
    LSTM(
        64,
        return_sequences=True,
        input_shape=(20, 5)
    ),

    Dropout(0.2),

    LSTM(32),

    Dense(16, activation="relu"),

    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    X,
    y,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

loss, accuracy = model.evaluate(X, y)

print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.4700 - loss: 0.6954 - val_accuracy: 0.4150 - val_loss: 0.6973
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5063 - loss: 0.6940 - val_accuracy: 0.4150 - val_loss: 0.6971
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4963 - loss: 0.6932 - val_accuracy: 0.5850 - val_loss: 0.6914
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4737 - loss: 0.6938 - val_accuracy: 0.5250 - val_loss: 0.6927
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4863 - loss: 0.6939 - val_accuracy: 0.4150 - val_loss: 0.6967
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5000 - loss: 0.6934 - val_accuracy: 0.4200 - val_loss: 0.6959
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4950 - loss: 0.6941 - val_accuracy: 0.5450 - val_loss: 0.6918
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5000 - loss: 0.6937 - val_accuracy: 0.4150 - val_loss: 0.6950
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5063 - loss: 0.6933 - val_accuracy: 0.4150 - val_loss: 0.6959
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5250 - loss: 0.6928 - val_accuracy: 0.4200 - val_loss: 0.6947
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4930 - loss: 0.6930
# Loss: 0.6930491924285889
# Accuracy: 0.49300000071525574
